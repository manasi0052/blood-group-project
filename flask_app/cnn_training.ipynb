# %% [markdown]
# # Convolutional Neural Network

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from PIL import Image

# %%
tf.__version__
# Out:
# '2.19.0'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')
# Out:
# Found 4841 images belonging to 8 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 1166 images belonging to 8 classes.

# %%
training_set.class_indices
# Out:
# {'A+': 0, 'A-': 1, 'AB+': 2, 'AB-': 3, 'B+': 4, 'B-': 5, 'O+': 6, 'O-': 7}

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[224, 224, 3]))

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=8, activation='softmax'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# ── Define callbacks ─────────────────────────────────────────────────────
checkpoint = ModelCheckpoint(
    'model/final_cnn.h5',      # where to save the best model
    monitor='val_accuracy',    # which metric to watch
    verbose=1,                 # log to console when it saves
    save_best_only=True        # only overwrite when val_accuracy improves
)
earlystop = EarlyStopping(
    monitor='val_accuracy',    # watch validation accuracy
    patience=5,                # stop if no improvement for 5 epochs
    restore_best_weights=True  # roll back to best epoch’s weights
)

# ── Compile ──────────────────────────────────────────────────────────────
cnn.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ── Fit with callbacks ──────────────────────────────────────────────────
history = cnn.fit(
    x=training_set,
    validation_data=test_set,
    epochs=100,                   
    callbacks=[checkpoint, earlystop]
)

# ── (no more cnn.save() here) ───────────────────────────────────────────
# The ModelCheckpoint callback has already saved the best model to model/final_cnn.h5
# Out:
# Epoch 1/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7424 - loss: 0.6190
# Epoch 1: val_accuracy improved from -inf to 0.86021, saving model to model/final_cnn.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 249s 2s/step - accuracy: 0.7425 - loss: 0.6188 - val_accuracy: 0.8602 - val_loss: 0.3786
# Epoch 2/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7583 - loss: 0.5776
# Epoch 2: val_accuracy did not improve from 0.86021
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 250s 2s/step - accuracy: 0.7583 - loss: 0.5777 - val_accuracy: 0.8482 - val_loss: 0.4222
# Epoch 3/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7798 - loss: 0.5299
# ...

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
test_image = image.load_img('dataset/A-.BMP', target_size = (224, 224))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)

predicted_class_index=np.argmax(result)

class_indices=training_set.class_indices

blood_groups={v:k for k,v in class_indices.items()}

prediction=blood_groups[predicted_class_index]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step

# %%
print("Predicted blood group",prediction)
# Out:
# Predicted blood group A-

# %%
# ✅ Step 4: Save model to Flask app
if 'cnn' in globals():
	cnn.save('model/final_cnn.h5')
else:
	print("Error: The 'cnn' model is not defined. Please ensure all necessary cells are executed.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
print(os.path.exists("model/final_cnn.h5"))
# Out:
# True

# %%
from tensorflow.keras.models import load_model

model = load_model('model/final_cnn.h5')
print("Input shape:", model.input_shape)
model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Input shape: (None, 224, 224, 3)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 109, 109, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...
